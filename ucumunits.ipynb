# %%
import pandas as pd

# %%
uri ='https://labterminologie.nl/art-decor/lab-units'
html = pd.read_html(uri)
transaction = html[1] # First table is overhead
transaction.head()
# Out:
#     0   1
# 0 NaN NaN
# 1 NaN NaN
# 2 NaN NaN
# 3 NaN NaN

# %%
html[5][20:40]
# Out:
#       0    1    2             3                           4  \
# 20  NaN  NaN  NaN        /[HPF]        per high power field
# 21  NaN  NaN  NaN           NaN                         NaN
# 22  NaN  NaN  NaN         /[IU]      per international unit
# 23  NaN  NaN  NaN           NaN                         NaN
# 24  NaN  NaN  NaN        /[LPF]  per low power field (100x)
# 25  NaN  NaN  NaN           NaN                         NaN
# 26  NaN  NaN  NaN     /g{creat}      per gram of creatinine
# 27  NaN  NaN  NaN           NaN                         NaN
# 28  NaN  NaN  NaN        /g{Hb}      per gram of hemoglobin
# 29  NaN  NaN  NaN           NaN                         NaN
# 30  NaN  NaN  NaN   /g{tot'nit}  per gram of total nitrogen
# 31  NaN  NaN  NaN           NaN                         NaN
# 32  NaN  NaN  NaN  /g{tot'prot}   per gram of total protein
# 33  NaN  NaN  NaN           NaN                         NaN
# 34  NaN  NaN  NaN   /g{wet'tis}      per gram of wet tissue
# ...

# %%
df = html[5]

# %%
df2 = df[df[4].notna()][[3, 4, 5]]

# %%
df2.columns = ['ucum', 'en', 'nl']

# %%
df2
# Out:
#                 ucum                              en  \
# 0           Eenheden                        Eenheden
# 1           Eenheden                            Naam
# 12         {Z-score}                       {Z-score}
# 14                 %                         percent
# 16       %{CDT_IFCC}  Percent CDT(IFCC standardised)
# ..               ...                             ...
# 362     {mm/dd/yyyy}              datum (dd-mm-jjjj)
# 364  {molaire ratio}                   {molar ratio}
# 366        {OD'unit}           Optical density units
# 368          {ratio}                         {ratio}
# 370          {titer}                           titer
#
#                                         nl
# 0                                 Eenheden
# 1                                     Naam
# 12                                 Z-score
# 14                                 procent
# 16   Percentage CDT(IFCC gestandardiseerd)
# ..                                     ...
# ...

# %%
df2.to_csv('ucum.csv')
