# %%
import pandas as pd
import os
pd.set_option('display.max_rows', 1000)

# %%
nw = 'C:/Users/marcd/Desktop/LCN-generatie-10-02-2023.xlsx'
ol = 'C:/Users/marcd/Desktop/LOINC-nlnames-2.73-patch.xlsx'

# %%
new = pd.read_excel(nw)
new
# Out:
#      LOINC-id                                        English LCN  \
# 0     74623-0  1,1-Dimethoxy-(9Z)octadecene (DMA 18:1) [Moles...
# 1     74621-4  1,1-Dimethoxy-(9Z)octadecene (DMA 18:1)/Oleate...
# 2     74627-1  1,1-Dimethoxyhexadecane (DMA 16:0) [Moles/mass...
# 3     74625-5  1,1-Dimethoxyhexadecane (DMA 16:0)/palmitate (...
# 4     74619-8  1,1-Dimethoxyoctadecane (DMA 18:0) [Moles/mass...
# ...       ...                                                ...
# 6196  10952-0  Swine urine proteins IgE Ab [Units/volume] in ...
# 6197  16044-0  Swine urine proteins IgE Ab RAST class [Presen...
# 6198   7215-7        Swiss Cheese IgE Ab [Units/volume] in Serum
# 6199  15627-3  Swiss Cheese IgE Ab RAST class [Presence] in S...
# 6200  56399-9        Swiss Cheese IgG4 Ab [Mass/volume] in Serum
#
#                                               Dutch LCN  \
# 0     1,1-Dimethoxy-(9z)octadeceen [mol/massa] in er...
# 1     1,1-Dimethoxy-(9z)octadeceen/oleaat [molaire v...
# ...

# %%
new[new['LOINC-id'] == '32401-2']
# Out:
# Empty DataFrame
# Columns: [LOINC-id, English LCN, Dutch LCN, Generated translation, Identical]
# Index: []
